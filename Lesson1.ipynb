# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

print("Python is ready!")
print(f"Pandas version: {pd.__version__}")

# Your first Edmonton real estate snippet
neighborhoods = {
    "Oliver":     310000,
    "Glenora":    680000,
    "Mill Woods": 355000,
    "Windermere": 590000
}

for name, price in neighborhoods.items():
    tier = "premium" if price > 500000 else "mid-range" if price > 350000 else "entry"
    print(f"{name}: ${price:,} — {tier}")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Fontconfig warning: ignoring UTF-8: not a valid region tag
# Python is ready!
# Pandas version: 2.3.3
# Oliver: $310,000 — entry
# Glenora: $680,000 — premium
# Mill Woods: $355,000 — mid-range
# Windermere: $590,000 — premium
